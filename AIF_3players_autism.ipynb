# %%
import random
random.seed(42)
np.random.seed(42)

import numpy as np
from scipy.stats import norm

import pymdp
from pymdp import utils
from pymdp.agent import Agent

import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import matplotlib.cm as cm
from mpl_toolkits.axes_grid1 import make_axes_locatable
import seaborn as sns

from river.preprocessing import StandardScaler
from river.drift import ADWIN
from river.ensemble import SRPRegressor
from river.tree import HoeffdingTreeRegressor

import warnings
warnings.filterwarnings('ignore')

# %%
def get_most_probable_indices(qs):
    return [np.argmax(q) for q in qs]

# %%
def get_max_prob_index(prob_array):
    return int(np.argmax(prob_array))

# %%
def step_print(produzione1, produzione2, produzione3, segnale1, segnale2, segnale3, vendite1, vendite2, vendite3, magazzino1, magazzino2, magazzino3, ware_levels):
    print(f"Produzione 1: {produzione1}, Produzione 2: {produzione2}, Produzione 3: {produzione3}")
    print(f"Segnale analisi 1: {segnale1}, Segnale analisi 2: {segnale2}, Segnale analisi 3: {segnale3}")
    print(f"Vendite 1: {vendite1}, Vendite 2: {vendite2}, Vendite 3: {vendite3}")
    print(f"Magazzino 1: {magazzino1, ware_levels[0]}, Magazzino 2: {magazzino2, ware_levels[1]}, Magazzino 3: {magazzino3, ware_levels[2]}")
    print("--------------------------------------------------")

# %%
def return_level(warehouses,pf_lev, ic_lev, oc_lev):
    levels = [""] * len(warehouses)
    for i,j in enumerate(warehouses):
        if j < pf_lev:
            levels[i] = "perfect"
        elif pf_lev-1 < j < ic_lev:
            levels[i] = "in control"
        elif j > oc_lev:
            levels[i] = "out of control"
        else:
            levels[i] = "loading"
    return levels

# %%
def revenue(market_price, sales): 
    C_gain = (market_price)*sales 
    return C_gain

# %%
SRP_1 = (StandardScaler() |
        SRPRegressor(
            n_models=10,
            seed=1,
            drift_detector=ADWIN(delta=0.001),
            warning_detector=ADWIN(delta=0.01),
            model = HoeffdingTreeRegressor(
                grace_period=50,
                leaf_prediction='adaptive',
                model_selector_decay=0.9,                
            )            
        ))

SRP_2 = (StandardScaler() |
        SRPRegressor(
            n_models=10,
            seed=1,
            drift_detector=ADWIN(delta=0.001),
            warning_detector=ADWIN(delta=0.01),
            model = HoeffdingTreeRegressor(
                grace_period=50,
                leaf_prediction='adaptive',
                model_selector_decay=0.9,               
            )            
        ))

SRP_3 = (StandardScaler() |
        SRPRegressor(
            n_models=10,
            seed=1,
            drift_detector=ADWIN(delta=0.001),
            warning_detector=ADWIN(delta=0.01),
            model = HoeffdingTreeRegressor(
                grace_period=50,
                leaf_prediction='adaptive',
                model_selector_decay=0.9,               
            )            
        ))

# %%
def revenue_SRP(SRP_model, my_sales, sales_competitor1, sales_competitor2):
    gains = []
    for prod in my_sales:
        # Create a feature dictionary for each instance.
        # Adjust the key names according to your feature naming.
        instance = {
            'prod_1': prod,
            'prod_2': sales_competitor1,
            'prod_3': sales_competitor2
        }
        # Predict the market price for this instance.
        predicted_price = SRP_model.predict_one(instance)
        # Compute the gain for this production level.
        c_gain = (predicted_price) * prod 
        gains.append(c_gain)
    return np.array(gains)

# %%
def build_transition_matrix(preferred_sales, state_warehouse, action_production, size_warehouse, std_dev=1.0):
    """
    Constructs the transition matrix B[s', s, a] that assigns a probability
    to each subsequent state s' given a current state s and an action a.
    
    Parameters:
    - preferred_sales: int, the target warehouse level
    - state_warehouse: list or array of warehouse states
    - action_production: list or array of production actions
    - size_warehouse: int, maximum warehouse capacity
    - std_dev: float, standard deviation of the transition noise
    
    Returns:
    - B: 3D ndarray with shape (s_prime, s, a)
    """
    B = np.zeros((len(state_warehouse), len(state_warehouse), len(action_production)))

    for s in range(len(state_warehouse)):  # Current state
        for a in range(len(action_production)):  # Production action
            # Distribution center = state + production - target
            mu = s + a - preferred_sales
            mu = np.clip(mu, 0, size_warehouse - 1)

            for s_prime in range(len(state_warehouse)):
                prob = norm.pdf(s_prime, loc=mu, scale=std_dev)
                B[s_prime, s, a] = prob

            # Normalize the column to create a probability distribution
            B[:, s, a] /= B[:, s, a].sum()

    return B

# %% [markdown]
# # States, Observations and Actions

# %% [markdown]
# ## States

# %%
max_warehouse = 10
size_warehouse = max_warehouse + 1
max_production = 6
n_action = max_production + 1

# states
state_warehouse = np.arange(0, size_warehouse)
state_context = ['OK production', 'Reduce production']
state_epistemic = ['Epistemic', 'Non-epistemic']


# number of states
n_states = [len(state_warehouse), len(state_context), len(state_epistemic)]

# number of factors
n_factors = len(n_states)

# %% [markdown]
# ## Actions

# %%
# production 
action_production = np.arange(0, n_action)
action_context = ['DN']
action_analysis = ['Do nothing', 'Ware analysis']

# number of actions
n_controls = [len(action_production), len(action_analysis)]

# %% [markdown]
# ## Observations

# %%
# my items sold
obs_sales = np.arange(0, size_warehouse)
obs_last_production = np.arange(0, n_action)
obs_level_ware = ["perfect", "in control", "loading", "out of control"]
obs_analysis = ["Null", "Analysis"]

num_obs = [len(obs_sales), len(obs_last_production), len(obs_level_ware), len(obs_analysis)]
num_modalities = len(num_obs)

# %% [markdown]
# ## BR dynamics

# %%
# when dealing with 3 players defining a proper framework can be difficult
def compute_desired_cost(BR1, BR2, BR3, max_customer_price, sensibility):
    """
    Compute cost_prod_1, cost_prod_2, cost_prod_3 such that the
    given BR1, BR2, BR3 satisfy:
      BR_i = (max_customer_price - 4*c_i + c_j + c_k) / (4*sensibility)

    Returns (cost_prod_1, cost_prod_2, cost_prod_3).
    """
    a = max_customer_price
    b = sensibility

    cost_prod_1 = a/2 - b*(6*BR1 + 2*BR2 + 2*BR3)/5
    cost_prod_2 = a/2 - b*(2*BR1 + 6*BR2 + 2*BR3)/5
    cost_prod_3 = a/2 - b*(2*BR1 + 2*BR2 + 6*BR3)/5

    return cost_prod_1, cost_prod_2, cost_prod_3

# %%
assumed_market_price_1 = 30
assumed_market_price_2 = 30
assumed_market_price_3 = 30

max_customer_price = 30
sensibility = 1

cost_prod = compute_desired_cost(BR1=5, BR2=4, BR3=3, 
                                 max_customer_price=max_customer_price, 
                                 sensibility=sensibility)

print(f"Computed costs: {cost_prod}")

cost_prod_1, cost_prod_2, cost_prod_3 = cost_prod

# (3pl) BR_i = (a-4*c_i + sum(c_{-i}))/(4*b)
BR_1 = (max_customer_price - 4 * cost_prod_1 + cost_prod_2 + cost_prod_3) / (4*sensibility)
BR_2 = (max_customer_price - 4 * cost_prod_2 + cost_prod_3 + cost_prod_1) / (4*sensibility)
BR_3 = (max_customer_price - 4 * cost_prod_3 + cost_prod_1 + cost_prod_2) / (4*sensibility)
BR_1_idx = round(BR_1)
BR_2_idx = round(BR_2)
BR_3_idx = round(BR_3)
print(f'Best response for industry 1: {BR_1}')
print(f'Best response for industry 2: {BR_2}')
print(f'Best response for industry 3: {BR_3}')
# Out:
# Computed costs: (6.199999999999999, 7.0, 7.8)
# Best response for industry 1: 5.000000000000001
# Best response for industry 2: 4.0
# Best response for industry 3: 3.0

# %% [markdown]
# # Likelihood matrices

# %%
A1 = utils.obj_array(num_modalities)
A2 = utils.obj_array(num_modalities)
A3 = utils.obj_array(num_modalities)

# %% [markdown]
# ## A[sales]

# %%
A1_sales = np.zeros((len(obs_sales),len(state_warehouse), len(state_context), len(state_epistemic)))
A3_sales = np.zeros((len(obs_sales),len(state_warehouse), len(state_context), len(state_epistemic)))

for i, state in enumerate(state_context):

    if state == 'OK production':
        soglia = 5  # threshold after which the mean remains fixed
        base_std = 2  # initial standard deviation
        std_growth = 0.05  # standard deviation growth after the threshold
    else:
        soglia = 7  # threshold after which the mean remains fixed
        base_std = 1.5  # initial standard deviation
        std_growth = 0.05  # standard deviation growth after the threshold

    for idx, epist in enumerate(state_epistemic):

        for j, n in enumerate(state_warehouse):

            mu = max(0, soglia-n)
            sigma = base_std + std_growth * n  # increases with n

            # Calculate the normal distribution for each observed sales value
            A1_sales[:, j, i, idx] = norm.pdf(obs_sales, loc=mu, scale=sigma)

            # Normalize the column to make it a probability distribution
            A1_sales[:, j, i, idx] /= A1_sales[:, j, i, idx].sum()


A1[0] = A1_sales
A3[0] = A1_sales


matrix = A1_sales[:,:,0,0]
plt.imshow(matrix, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.title("acceptable production")
plt.show()

matrix = A1_sales[:,:,1,0]
plt.imshow(matrix, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.title("reduce production")
plt.show()

# %%
A2_sales = np.zeros((len(obs_sales),len(state_warehouse), len(state_context), len(state_epistemic)))

for i, state in enumerate(state_context):

    if state == 'OK production':
        soglia = 5  # threshold after which the mean remains fixed
        base_std = 0.6  # initial standard deviation
        std_growth = 0.05  # standard deviation growth after the threshold
    else:
        soglia = 7  # threshold after which the mean remains fixed
        base_std = 0.1  # initial standard deviation
        std_growth = 0.05  # standard deviation growth after the threshold

    for idx, epist in enumerate(state_epistemic):

        for j, n in enumerate(state_warehouse):

            mu = max(0, soglia-n)
            sigma = base_std + std_growth * n  # increases with n

            # Calculate the normal distribution for each observed sales value
            A2_sales[:, j, i, idx] = norm.pdf(obs_sales, loc=mu, scale=sigma)

            # Normalize the column to make it a probability distribution
            A2_sales[:, j, i, idx] /= A2_sales[:, j, i, idx].sum()


A2[0] = A2_sales

# %%
# Common color scale limits
vmin = 0.0
vmax = 0.35

# First plot: acceptable production
matrix = A1_sales[:, :, 0, 0]
plt.imshow(matrix, cmap='viridis', interpolation='nearest', vmin=vmin, vmax=vmax)
plt.colorbar()
plt.ylabel("obs sales")
plt.xlabel("state warehouse")
plt.title("acceptable production")
plt.show()

# Second plot: reduce production
matrix = A1_sales[:, :, 1, 0]
plt.imshow(matrix, cmap='viridis', interpolation='nearest', vmin=vmin, vmax=vmax)
plt.colorbar()
plt.ylabel("obs sales")
plt.xlabel("state warehouse")
plt.title("reduce production")
plt.show()

# %% [markdown]
# ## A[last action]

# %%
A1_production = np.zeros((len(obs_last_production),len(state_warehouse), len(state_context), len(state_epistemic)))
#A2_production = np.zeros((len(obs_last_production),len(state_warehouse), len(state_context), len(state_epistemic)))



for i, state in enumerate(state_context):

    if state == 'OK production':
        max_prod = n_action - 1
        base_std = 2.5  # standard deviation
        reverse_strength = 4.0  # how quickly the mean decreases
    else:
        max_prod = n_action - 1
        base_std = 2.5  # standard deviation
        reverse_strength = 8.0  # how quickly the mean decreases

    for idx, epist in enumerate(state_epistemic):
        
        for j, n in enumerate(state_warehouse):
            # Production mean decreases linearly with warehouse level
            mu = max_prod * np.exp(-reverse_strength * n / state_warehouse[-1])
            sigma = base_std

            A1_production[:, j, i, idx] = norm.pdf(obs_last_production, loc=mu, scale=sigma)
            # Normalize the column to make it a probability distribution
            A1_production[:, j, i, idx] /= A1_production[:, j, i, idx].sum()


A1[1] = A1_production
A2[1] = A1_production
A3[1] = A1_production

matrix = A1_production[:,:,0,1]
plt.imshow(matrix, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.ylabel("obs sales")
plt.xlabel("state warehouse")
plt.title("acceptable production")
plt.show()

matrix = A1_production[:,:,1,1]
plt.imshow(matrix, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.ylabel("obs sales")
plt.xlabel("state warehouse")
plt.title("reduce production")
plt.show()

# %% [markdown]
# ## A[level_ware]

# %%
pf_level = 3
ic_level = 5
oc_level = 8

# %%
# Initialize the full A1_ware matrix
n_obs    = len(obs_level_ware)
n_ware   = len(state_warehouse)
n_ctx    = len(state_context)
n_epist  = len(state_epistemic)

A1_ware = np.zeros((n_obs, n_ware, n_ctx, n_epist))

# First, reconstruct the old base matrix without context
A_base = np.zeros((n_obs, n_ware, n_epist))

for idx_e, epist in enumerate(state_epistemic):
    if epist == "Epistemic":
        # Deterministic case
        for j, level in enumerate(obs_level_ware):
            if level == "perfect":
                A_base[j, :pf_level, idx_e] = 1
            elif level == "in control":
                A_base[j, pf_level:ic_level, idx_e] = 1
            elif level == "loading":
                A_base[j, ic_level:oc_level, idx_e] = 1
            elif level == "out of control":
                A_base[j, oc_level:, idx_e] = 1
    else:
        # "Noisy" case based on the Epistemic slice
        noise_std = 0.4
        base = A_base[:, :, state_epistemic.index("Epistemic")]

        for w in range(n_ware):
            col_base = base[:, w]
            centers = np.where(col_base > 0)[0]
            if len(centers) == 0:
                A_base[:, w, idx_e] = 1.0 / n_obs
            else:
                noisy_col = np.zeros(n_obs)
                for c0 in centers:
                    distances = np.abs(np.arange(n_obs) - c0)
                    gaussian = np.exp(-(distances**2) / (2 * noise_std**2))
                    noisy_col += gaussian
                noisy_col = np.clip(noisy_col, 0, None)
                noisy_col /= noisy_col.sum()
                A_base[:, w, idx_e] = noisy_col

# Define the weights P(context | observation)
# Row = observation, Column = context
context_weights = np.array([
    [0.99, 0.01],  # perfect
    [0.80, 0.20],  # in control
    [0.20, 0.80],  # loading
    [0.01, 0.99],  # out of control
])  # shape = (n_obs, n_ctx)

# Expand A_base onto the context dimension and re-normalize
for e in range(n_epist):
    for w in range(n_ware):
        base_col = A_base[:, w, e]
        for c in range(n_ctx):
            raw = base_col * context_weights[:, c]
            if raw.sum() == 0:
                # Fallback (if all zeros for some column)
                raw = base_col.copy()
            A1_ware[:, w, c, e] = raw / raw.sum()

# Assign to pymdp matrices
A1[2] = A1_ware
A2[2] = A1_ware
A3[2] = A1_ware

# Verification
assert utils.is_normalized(A1_ware), "A1_ware is NOT normalized!"

# %%
matrix = A1_ware[:,:,0,1]
plt.imshow(matrix, cmap='viridis', interpolation='nearest', vmin=0, vmax=1)
plt.colorbar()
plt.ylabel("level signal")
plt.xlabel("state warehouse")
plt.title("acceptable production")
plt.show()

matrix = A1_ware[:,:,1,1]
plt.imshow(matrix, cmap='viridis', interpolation='nearest', vmin=0, vmax=1)
plt.colorbar()
plt.ylabel("level signal")
plt.xlabel("state warehouse")
plt.title("reduce production")
plt.show()

matrix = A1_ware[:,:,0,0]
plt.imshow(matrix, cmap='viridis', interpolation='nearest', vmin=0, vmax=1)
plt.colorbar()
plt.ylabel("level signal")
plt.xlabel("state warehouse")
plt.title("epistemic (noiseless) signal")
plt.show()

# %% [markdown]
# ## A[analysis]

# %%
A1_analysis = np.zeros((len(obs_analysis),len(state_warehouse),len(state_context),len(state_epistemic)))

for j, state in enumerate(state_context):
    for i, ware in enumerate(state_warehouse):
        A1_analysis[1,i,j,0] = 1
        A1_analysis[0,i,j,1] = 1

A1[3] = A1_analysis
A2[3] = A1_analysis
A3[3] = A1_analysis

matrix = A1_analysis[:,6,1,:]
plt.imshow(matrix, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.show()

# %% [markdown]
# # Transition probabilities matrices

# %%
B1 = utils.obj_array(n_factors)
B2 = utils.obj_array(n_factors)
B3 = utils.obj_array(n_factors)

# %% [markdown]
# ## B[warehouse]

# %%
B_warehouse1 = np.zeros((len(state_warehouse), len(state_warehouse), len(action_production)))

preferred_sales = BR_1_idx  # target state is s-2
# Noise parameter
std_dev = 1.0  # standard deviation of the noise

for s in range(len(state_warehouse)):  # Initial state
    for a in range(len(action_production)):  # Production action

        # Distribution center = state + production - 2
        mu = s + a - preferred_sales
        mu = np.clip(mu, 0, size_warehouse - 1)

        for s_prime in range(len(state_warehouse)):
            prob = norm.pdf(s_prime, loc=mu, scale=std_dev)
            B_warehouse1[s_prime, s, a] = prob

        # Normalize the column to make it a probability distribution
        B_warehouse1[:, s, a] /= B_warehouse1[:, s, a].sum()

# %%
B_warehouse2 = np.zeros((len(state_warehouse), len(state_warehouse), len(action_production)))

preferred_sales = BR_2_idx  # target state is s-2
# Noise parameter
std_dev = 1.0  # standard deviation of the noise

for s in range(len(state_warehouse)):  # Initial state
    for a in range(len(action_production)):  # Production action

        # Distribution center = state + production - 2
        mu = s + a - preferred_sales
        mu = np.clip(mu, 0, size_warehouse - 1)

        for s_prime in range(len(state_warehouse)):
            prob = norm.pdf(s_prime, loc=mu, scale=std_dev)
            B_warehouse2[s_prime, s, a] = prob

        # Normalize the column to make it a probability distribution
        B_warehouse2[:, s, a] /= B_warehouse2[:, s, a].sum()

# %%
B_warehouse3 = np.zeros((len(state_warehouse), len(state_warehouse), len(action_production)))

preferred_sales = BR_3_idx  # target state is s-2
# Noise parameter
std_dev = 1.0  # standard deviation of the noise

for s in range(len(state_warehouse)):  # Initial state
    for a in range(len(action_production)):  # Production action

        # Distribution center = state + production - 2
        mu = s + a - preferred_sales
        mu = np.clip(mu, 0, size_warehouse - 1)

        for s_prime in range(len(state_warehouse)):
            prob = norm.pdf(s_prime, loc=mu, scale=std_dev)
            B_warehouse3[s_prime, s, a] = prob

        # Normalize the column to create a probability distribution
        B_warehouse3[:, s, a] /= B_warehouse3[:, s, a].sum()

# %%
B1[0] = B_warehouse1
B2[0] = B_warehouse2
B3[0] = B_warehouse3

# %%
# Determine the number of rows and columns for the subplots
matrix = B_warehouse1
n_actions = matrix.shape[2]
n_cols = 4 #int(np.ceil(np.sqrt(n_actions)))
n_rows = 2 #int(np.ceil(n_actions / n_cols))

fig, axes = plt.subplots(n_rows, n_cols, figsize=(4 * n_cols, 4 * n_rows))

# Flatten the axes for easy iteration (works even if the grid is not square)
axes = axes.flatten()

for i in range(n_actions):
    im = axes[i].imshow(matrix[:, :, i], cmap='viridis', interpolation='nearest')
    axes[i].set_title(f'Action production = {i}')
    axes[i].set_xlabel('initial warehouse state')
    axes[i].set_ylabel('final warehouse state')
    fig.colorbar(im, ax=axes[i])

# Hide any empty subplots
for j in range(n_actions, len(axes)):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## B[context]

# %%
B_context = np.zeros((len(state_context), len(state_context), len(action_context)))

p_correct = 0.5 

for a in range(len(action_context)):
    for s in range(len(state_context)):
        for s_prime in range(len(state_context)):
            if s_prime == s:
                B_context[s_prime, s, a] = p_correct
            else:                    
                B_context[s_prime, s, a] = (1 - p_correct) / (len(state_context) - 1)
    B_context[:, :, a] /= B_context[:, :, a].sum(axis=0)

B1[1] = B_context
B2[1] = B_context
B3[1] = B_context

# %% [markdown]
# ## B[state]

# %%
B_epistemic = np.zeros((len(state_epistemic), len(state_epistemic), len(action_analysis)))

for i, a in enumerate(action_analysis):
    if a == 'Ware analysis':
        B_epistemic[0,:,i] = 1
    else:
        B_epistemic[1,:,i] = 1 

B1[2] = B_epistemic
B2[2] = B_epistemic
B3[2] = B_epistemic

# %% [markdown]
# # Goal prior

# %%
C1 = utils.obj_array_zeros(num_obs)
C2 = utils.obj_array_zeros(num_obs)
C3 = utils.obj_array_zeros(num_obs)

# %% [markdown]
# ## C[sales]

# %%
C_sales_1 = revenue(market_price=assumed_market_price_1, sales=obs_sales)
C_sales_2 = revenue(market_price=assumed_market_price_2, sales=obs_sales)
C_sales_3 = revenue(market_price=assumed_market_price_3, sales=obs_sales)

C1[0] = C_sales_1
C2[0] = C_sales_2
C3[0] = C_sales_3

# %% [markdown]
# ## C[production]

# %%
C_production_1 = -cost_prod_1 * action_production
C_production_2 = -cost_prod_2 * action_production
C_production_3 = -cost_prod_3 * action_production

C1[1] = C_production_1
C2[1] = C_production_2
C3[1] = C_production_3

# %% [markdown]
# ## C[ware]
# Se supero una certa soglia magari devo sostenere dei costi di gestione maggiori, se la situazione è critica dei costi di smaltimento.

# %%
C_ware = np.array([0, -15, -75, -100])

C1[2] = C_ware
C2[2] = C_ware
C3[2] = C_ware

# %% [markdown]
# ## C[analysis]

# %%
C_analysis = np.array([0, -3.5])

C1[3] = C_analysis
C2[3] = C_analysis
C3[3] = C_analysis

# %% [markdown]
# # State Prior

# %%
D1 = utils.obj_array(n_factors)
D2 = utils.obj_array(n_factors)
D3 = utils.obj_array(n_factors)

D_warehouse = utils.onehot(0, len(state_warehouse))
D_context = utils.onehot(0, len(state_context))
D_epistemic = utils.onehot(1, len(state_epistemic))

D1[0] = D_warehouse
D2[0] = D_warehouse
D3[0] = D_warehouse

D1[1] = D_context
D2[1] = D_context
D3[1] = D_context

D1[2] = D_epistemic
D2[2] = D_epistemic
D3[2] = D_epistemic

# %% [markdown]
# # Agent initialization

# %%
B1_prior = utils.dirichlet_like(B1)
B2_prior = utils.dirichlet_like(B2)
B3_prior = utils.dirichlet_like(B3)

# %%
my_agent1 = Agent(A = A1, B = B1, C = C1, D = D1, policy_len=3,
                  use_states_info_gain = False,
                  use_param_info_gain = True,
                  scale_state=0.1)

# %%
my_agent2 = Agent(A = A2, B = B2, C = C2, D = D2, policy_len=3,
                  use_states_info_gain = False,
                  use_param_info_gain = True,
                  scale_state=0.1)

# %%
my_agent3 = Agent(A = A3, B = B3, C = C3, D = D3, policy_len=3,
                  use_states_info_gain = False,
                  use_param_info_gain = True,
                  scale_state=0.1)

# %% [markdown]
# # Environment

# %%
class CournotMarket(object):

    def __init__(self, 
                 reputation=(1/3, 1/3, 1/3), 
                 total_demand=5, 
                 max_customer_price=10, 
                 sensibility=1, 
                 warehouse_1=0, 
                 warehouse_2=0, 
                 warehouse_3=0):
        # --- Validate and normalize reputation vector ---
        if not hasattr(reputation, "__iter__") or len(reputation) != 3:
            raise ValueError("reputation must be a sequence of three numeric values (e.g. [0.3, 0.4, 0.3]).")

        reputation = [float(r) for r in reputation]
        total_rep = sum(reputation)

        if total_rep <= 0:
            raise ValueError("Reputation values must be positive and sum to a positive number.")

        # Automatically normalize to sum to 1
        reputation = [r / total_rep for r in reputation]
        self.reputation = tuple(reputation)

        # --- Store other parameters ---
        self.total_demand = float(total_demand)
        self.max_customer_price = float(max_customer_price)
        self.sensibility = float(sensibility)
        self.warehouse_1 = int(warehouse_1)
        self.warehouse_2 = int(warehouse_2)
        self.warehouse_3 = int(warehouse_3)
    

    def step(self, action1, action2, action3, time_step):
        # --- (Optional dynamic demand logic)
        if time_step == 6:
            self.total_demand = 12
        if time_step == 11: 
            self.total_demand = 9
        if time_step == 15:
            self.total_demand = 20
            self.max_customer_price = 45

        real_total_demand = self.total_demand
        print(f"Real total demand: {real_total_demand}")
        
        # --- Compute total available products per firm ---
        total_product = [
            action1[0] + self.warehouse_1,
            action2[0] + self.warehouse_2,
            action3[0] + self.warehouse_3
        ]
        product_availability = sum(total_product)

        # --- Market price adjustment based on total availability ---
        market_price = max(0, self.max_customer_price - self.sensibility * product_availability)

        # --- Preferred demand allocation (based on reputation) ---
        preferred_demand = [int(real_total_demand * r) for r in self.reputation]
        remainder = int(real_total_demand - sum(preferred_demand))
        if remainder > 0:
            # distribute remainder randomly or to the most reputed firm
            preferred_demand[preferred_demand.index(max(preferred_demand))] += remainder

        # --- Actual sales limited by availability ---
        actual_sales = [min(total_product[i], preferred_demand[i]) for i in range(3)]

        # --- Remaining unsatisfied demand per firm ---
        remaining_demand = [preferred_demand[i] - actual_sales[i] for i in range(3)]

        # --- Redistribution of unmet demand to firms with remaining stock ---
        for i in range(3):
            if remaining_demand[i] > 0:
                # Find firms with spare stock
                for j in range(3):
                    if j != i and total_product[j] > actual_sales[j]:
                        extra_sales = min(total_product[j] - actual_sales[j], remaining_demand[i])
                        actual_sales[j] += extra_sales
                        remaining_demand[i] -= extra_sales
                        if remaining_demand[i] <= 0:
                            break

        # --- Update warehouses ---
        new_warehouses = [total_product[i] - actual_sales[i] for i in range(3)]
        self.warehouse_1, self.warehouse_2, self.warehouse_3 = new_warehouses

        # --- Record analyses ---
        analyses = []
        for action in [action1, action2, action3]:
            analyses.append("Analysis" if len(action) > 2 and action[2] == 1 else "Null")

        # --- Prepare observations ---
        obs_sales = [int(s) for s in actual_sales]
        obs_last_prod = [int(action1[0]), int(action2[0]), int(action3[0])]
        h_obs_warehouse = [int(w) for w in new_warehouses]
        obs_level_ware = return_level(h_obs_warehouse, pf_level, ic_level, oc_level)
        obs_analysis = analyses

        return obs_sales, market_price, obs_last_prod, obs_level_ware, obs_analysis, h_obs_warehouse

# %% [markdown]
# # Active Inference Loop

# %%
prod1 = []
prod2 = []
prod3 = []
warehouse1 = [0]
warehouse2 = [0]
warehouse3 = [0]
sold1 = []
sold2 = []
sold3 = []

infer_ware1 = []
infer_ware2 = []
infer_ware3 = []

infer_context1 = []
infer_context2 = []
infer_context3 = []

epistemic_choice1 = []
epistemic_choice2 = []
epistemic_choisce3 = []

real_price =[]
predicted_price1 = []
predicted_price2 = []
predicted_price3 = []

Belief_gain1 =[]
real_gain1 = []

Belief_gain2 =[]    
real_gain2 = []

Belief_gain3 =[]    
real_gain3 = []

BR_1_plot = []
BR_2_plot = []
BR_3_plot = []

Max_price = []

# %%
def run_active_inference_loop(my_agent1, my_agent2, my_agent3, my_env, size_warehouse, T=5):
    """Runs an active inference loop where alpha increases over time."""

    market_price = assumed_market_price_1
    size_ware = size_warehouse
    size_warehouse = np.arange(size_warehouse)
    obs1 = [0, 0, obs_level_ware.index("perfect"), obs_analysis.index("Null")] 
    obs2 = [0, 0, obs_level_ware.index("perfect"), obs_analysis.index("Null")]
    obs3 = [0, 0, obs_level_ware.index("perfect"), obs_analysis.index("Null")]

    starting_sales_states = [0, 0, 0]
    obs_last_sales = starting_sales_states

    # starting_sales_states = [0, 0, 0]
    # obs_last_sales = starting_sales_states

    null_instance = {f"prod_{i}": v for i, v in enumerate(obs_last_sales)}

    SRP_1.learn_one(null_instance, market_price)
    SRP_2.learn_one(null_instance, market_price)
    SRP_3.learn_one(null_instance, market_price)

    old_max_price_1 = SRP_1.predict_one(null_instance) 
    old_max_price_2 = SRP_2.predict_one(null_instance) 
    old_max_price_3 = SRP_3.predict_one(null_instance)

    BR_1 = (assumed_market_price_1 - 4 * cost_prod_1 + cost_prod_2 + cost_prod_3) / (4*sensibility)
    BR_2 = (assumed_market_price_2 - 4 * cost_prod_2 + cost_prod_3 + cost_prod_1) / (4*sensibility)
    BR_3 = (assumed_market_price_3 - 4 * cost_prod_3 + cost_prod_1 + cost_prod_2) / (4*sensibility)


    for t in range(T):
        qs_ware1, qs_ctx1, qs_epist1 = my_agent1.infer_states(obs1)
        qs_ware2, qs_ctx2, qs_epist2 = my_agent2.infer_states(obs2)
        qs_ware3, qs_ctx3, qs_epist3 = my_agent3.infer_states(obs3)
        print("supposed warehouse 1:", get_max_prob_index(qs_ware1))
        print("context 1:", get_max_prob_index(qs_ctx1))
        print("analisi 1:", get_max_prob_index(qs_epist1))
        print("supposed warehouse 2:", get_max_prob_index(qs_ware2))
        print("context 2:", get_max_prob_index(qs_ctx2))
        print("analisi 2:", get_max_prob_index(qs_epist2))
        print("supposed warehouse 3:", get_max_prob_index(qs_ware3))
        print("context 3:", get_max_prob_index(qs_ctx3))
        print("analisi 3:", get_max_prob_index(qs_epist3))
        
        # Update preference distribution (C matrix) using a custom revenue function
        print(obs_last_sales)
        my_agent1.C[0] = revenue_SRP(SRP_1, my_sales=size_warehouse, sales_competitor1=obs_last_sales[1], sales_competitor2=obs_last_sales[2])
        my_agent2.C[0] = revenue_SRP(SRP_2, my_sales=size_warehouse, sales_competitor1=obs_last_sales[0], sales_competitor2=obs_last_sales[2])
        my_agent3.C[0] = revenue_SRP(SRP_3, my_sales=size_warehouse, sales_competitor1=obs_last_sales[0], sales_competitor2=obs_last_sales[1])
        

        # Infer policies
        q_pi_1, efe_1 = my_agent1.infer_policies()
        q_pi_2, efe_2 = my_agent2.infer_policies()
        q_pi_3, efe_3 = my_agent3.infer_policies()

        # Sample actions based on stochastic policy selection
        action_1 = my_agent1.sample_action()
        action_2 = my_agent2.sample_action()
        action_3 = my_agent3.sample_action()
        
        # Environment step
        obs_sales, market_price, obs_last_prod, obs_level, obs_analysis_signal, h_obs_warehouse = my_env.step(action_1, action_2, action_3, t)

        step_print(produzione1=obs_last_prod[0], produzione2=obs_last_prod[1], produzione3=obs_last_prod[2],
                   segnale1=obs_analysis_signal[0], segnale2=obs_analysis_signal[1], segnale3=obs_analysis_signal[2],
                   vendite1=obs_sales[0], vendite2=obs_sales[1], vendite3=obs_sales[2],
                   magazzino1=h_obs_warehouse[0], magazzino2=h_obs_warehouse[1], magazzino3=h_obs_warehouse[2],
                   ware_levels=obs_level)

        instance = {f"prod_{i}": v for i, v in enumerate(obs_sales)}

        price_hat_1 = SRP_1.predict_one(instance)
        price_hat_2 = SRP_2.predict_one(instance)
        price_hat_3 = SRP_3.predict_one(instance)
        SRP_1.learn_one(instance, market_price)
        SRP_2.learn_one(instance, market_price)
        SRP_3.learn_one(instance, market_price)

        #---------- Update B (if needed) ----------------#
        Max_price.append(SRP_1.predict_one(null_instance))
        
        new_max_price_1 = SRP_1.predict_one(null_instance) + 5
        new_max_price_2 = SRP_2.predict_one(null_instance) + 5
        new_max_price_3 = SRP_3.predict_one(null_instance) + 5

        
        print("old max price 1:", old_max_price_1)
        print("new max price 1:", new_max_price_1)
        print("old max price 2:", old_max_price_2)
        print("new max price 2:", new_max_price_2)
        print("old max price 3:", old_max_price_3)
        print("new max price 3:", new_max_price_3)

        if (abs(new_max_price_1 - old_max_price_1))/old_max_price_1 > 0.2:
            BR_1 = (new_max_price_1 - 4 * cost_prod_1 + cost_prod_2 + cost_prod_3) / (4*sensibility)
            BR_1_idx = round(min(BR_1, max_production))
            print(f"NEW BR 1: {BR_1_idx}")
            B1_new = build_transition_matrix(preferred_sales=BR_1_idx, state_warehouse=state_warehouse, 
                                             action_production=action_production, size_warehouse=size_ware)
            my_agent1.B[0] = B1_new
        
        if (abs(new_max_price_2 - old_max_price_2))/old_max_price_2 > 0.2:
            BR_2 = (new_max_price_2 - 4 * cost_prod_2 + cost_prod_3 + cost_prod_1) / (4*sensibility)
            BR_2_idx = round(min(BR_2, max_production))
            print(f"NEW BR 2: {BR_2_idx}")
            B2_new = build_transition_matrix(preferred_sales=BR_2_idx, state_warehouse=state_warehouse, 
                                             action_production=action_production, size_warehouse=size_ware)
            my_agent2.B[0] = B2_new
        
        if (abs(new_max_price_3 - old_max_price_3))/old_max_price_3 > 0.2:
            BR_3 = (new_max_price_3 - 4 * cost_prod_2 + cost_prod_3 + cost_prod_1) / (4*sensibility)
            BR_3_idx = round(min(BR_3, max_production))
            print(f"NEW BR 3: {BR_3_idx}")
            B3_new = build_transition_matrix(preferred_sales=BR_3_idx, state_warehouse=state_warehouse, 
                                             action_production=action_production, size_warehouse=size_ware)
            my_agent3.B[0] = B3_new

        old_max_price_1 = new_max_price_1
        old_max_price_2 = new_max_price_2
        old_max_price_3 = new_max_price_3

        BR_1_plot.append(BR_1)
        BR_2_plot.append(BR_2)
        BR_3_plot.append(BR_3)

        #----------- end update section -----------------#

        # Update observations
        obs1 = [obs_sales[0], obs_last_prod[0], obs_level_ware.index(obs_level[0]), 
                obs_analysis.index(obs_analysis_signal[0])]
        obs2 = [obs_sales[1], obs_last_prod[1], obs_level_ware.index(obs_level[1]), 
                obs_analysis.index(obs_analysis_signal[1])]
        obs3 =  [obs_sales[2], obs_last_prod[2], obs_level_ware.index(obs_level[2]), 
                obs_analysis.index(obs_analysis_signal[2])]

        # per il prossimo step di training
        obs_last_sales = obs_sales

        # Plot variables

        # 1) plot about production and sales
        prod1.append(obs_last_prod[0])
        prod2.append(obs_last_prod[1])
        prod3.append(obs_last_prod[2])
        warehouse1.append(h_obs_warehouse[0])
        warehouse2.append(h_obs_warehouse[1])
        warehouse3.append(h_obs_warehouse[2])
        sold1.append(obs_sales[0])
        sold2.append(obs_sales[1])
        sold3.append(obs_sales[2])
        infer_ware1.append(get_max_prob_index(qs_ware1))
        infer_ware2.append(get_max_prob_index(qs_ware2))
        infer_ware3.append(get_max_prob_index(qs_ware3))

        epistemic_choice1.append(get_max_prob_index(qs_epist1))
        epistemic_choice2.append(get_max_prob_index(qs_epist2))
        epistemic_choisce3.append(get_max_prob_index(qs_epist3))

        infer_context1.append(get_max_prob_index(qs_ctx1))
        infer_context2.append(get_max_prob_index(qs_ctx2))
        infer_context3.append(get_max_prob_index(qs_ctx3))

        # 2) plot about price estimation
        real_price.append(market_price)
        predicted_price1.append(price_hat_1)
        predicted_price2.append(price_hat_2)
        predicted_price3.append(price_hat_3)

# %% [markdown]
# # Main

# %%
reputation_env = (1/3, 1/3, 1/3)
total_demand_env = 15
env = CournotMarket(reputation = reputation_env, total_demand = total_demand_env, 
                    max_customer_price = max_customer_price, sensibility = sensibility)

T = 25

run_active_inference_loop(my_agent1, my_agent2, my_agent3, env, size_warehouse=size_warehouse, T = T)
# Out:
# supposed warehouse 1: 0
# context 1: 0
# analisi 1: 1
# supposed warehouse 2: 0
# context 2: 0
# analisi 2: 1
# supposed warehouse 3: 0
# context 3: 0
# analisi 3: 1
# [0, 0, 0]
# Real total demand: 15.0
# Produzione 1: 6, Produzione 2: 6, Produzione 3: 5
# Segnale analisi 1: Analysis, Segnale analisi 2: Null, Segnale analisi 3: Null
# Vendite 1: 5, Vendite 2: 5, Vendite 3: 5
# Magazzino 1: (1, 'perfect'), Magazzino 2: (1, 'perfect'), Magazzino 3: (0, 'perfect')
# --------------------------------------------------
# old max price 1: 30.0
# new max price 1: 26.174011733880157
# old max price 2: 30.0
# new max price 2: 26.174011733880157
# old max price 3: 30.0
# new max price 3: 26.174011733880157
# supposed warehouse 1: 0
# context 1: 0
# analisi 1: 0
# supposed warehouse 2: 0
# context 2: 1
# analisi 2: 1
# supposed warehouse 3: 1
# context 3: 0
# analisi 3: 1
# [5, 5, 5]
# Real total demand: 15.0
# Produzione 1: 6, Produzione 2: 5, Produzione 3: 3
# Segnale analisi 1: Null, Segnale analisi 2: Null, Segnale analisi 3: Null
# Vendite 1: 7, Vendite 2: 5, Vendite 3: 3
# Magazzino 1: (0, 'perfect'), Magazzino 2: (1, 'perfect'), Magazzino 3: (0, 'perfect')
# --------------------------------------------------
# old max price 1: 26.174011733880157
# new max price 1: 23.45110867074102
# old max price 2: 26.174011733880157
# new max price 2: 23.45110867074102
# old max price 3: 26.174011733880157
# new max price 3: 23.45110867074102
# supposed warehouse 1: 0
# context 1: 1
# analisi 1: 1
# supposed warehouse 2: 0
# context 2: 1
# analisi 2: 1
# supposed warehouse 3: 2
# context 3: 0
# analisi 3: 1
# [7, 5, 3]
# Real total demand: 15.0
# Produzione 1: 6, Produzione 2: 5, Produzione 3: 3
# Segnale analisi 1: Null, Segnale analisi 2: Null, Segnale analisi 3: Null
# Vendite 1: 6, Vendite 2: 6, Vendite 3: 3
# Magazzino 1: (0, 'perfect'), Magazzino 2: (0, 'perfect'), Magazzino 3: (0, 'perfect')
# --------------------------------------------------
# old max price 1: 23.45110867074102
# new max price 1: 22.517109731898756
# old max price 2: 23.45110867074102
# new max price 2: 22.517109731898756
# old max price 3: 23.45110867074102
# new max price 3: 22.517109731898756
# supposed warehouse 1: 0
# context 1: 0
# analisi 1: 1
# supposed warehouse 2: 0
# context 2: 1
# analisi 2: 1
# supposed warehouse 3: 2
# context 3: 0
# analisi 3: 1
# [6, 6, 3]
# Real total demand: 15.0
# Produzione 1: 6, Produzione 2: 6, Produzione 3: 3
# Segnale analisi 1: Null, Segnale analisi 2: Null, Segnale analisi 3: Null
# Vendite 1: 6, Vendite 2: 6, Vendite 3: 3
# Magazzino 1: (0, 'perfect'), Magazzino 2: (0, 'perfect'), Magazzino 3: (0, 'perfect')
# --------------------------------------------------
# old max price 1: 22.517109731898756
# new max price 1: 22.037928545445972
# old max price 2: 22.517109731898756
# new max price 2: 22.037928545445972
# old max price 3: 22.517109731898756
# new max price 3: 22.037928545445972
# supposed warehouse 1: 0
# context 1: 0
# analisi 1: 1
# supposed warehouse 2: 0
# context 2: 1
# analisi 2: 1
# supposed warehouse 3: 2
# context 3: 0
# analisi 3: 1
# [6, 6, 3]
# Real total demand: 15.0
# Produzione 1: 6, Produzione 2: 6, Produzione 3: 3
# Segnale analisi 1: Null, Segnale analisi 2: Null, Segnale analisi 3: Null
# Vendite 1: 6, Vendite 2: 6, Vendite 3: 3
# Magazzino 1: (0, 'perfect'), Magazzino 2: (0, 'perfect'), Magazzino 3: (0, 'perfect')
# --------------------------------------------------
# old max price 1: 22.037928545445972
# new max price 1: 21.69626736882834
# old max price 2: 22.037928545445972
# new max price 2: 21.69626736882834
# old max price 3: 22.037928545445972
# new max price 3: 21.69626736882834
# supposed warehouse 1: 0
# context 1: 0
# analisi 1: 1
# supposed warehouse 2: 0
# context 2: 1
# analisi 2: 1
# supposed warehouse 3: 2
# context 3: 0
# analisi 3: 1
# [6, 6, 3]
# Real total demand: 15.0
# Produzione 1: 6, Produzione 2: 6, Produzione 3: 3
# Segnale analisi 1: Null, Segnale analisi 2: Null, Segnale analisi 3: Null
# Vendite 1: 6, Vendite 2: 6, Vendite 3: 3
# Magazzino 1: (0, 'perfect'), Magazzino 2: (0, 'perfect'), Magazzino 3: (0, 'perfect')
# --------------------------------------------------
# old max price 1: 21.69626736882834
# new max price 1: 21.477840383022603
# old max price 2: 21.69626736882834
# new max price 2: 21.477840383022603
# old max price 3: 21.69626736882834
# new max price 3: 21.477840383022603
# supposed warehouse 1: 0
# context 1: 0
# analisi 1: 1
# supposed warehouse 2: 0
# context 2: 1
# analisi 2: 1
# supposed warehouse 3: 2
# context 3: 0
# analisi 3: 1
# [6, 6, 3]
# Real total demand: 12
# Produzione 1: 6, Produzione 2: 6, Produzione 3: 3
# Segnale analisi 1: Null, Segnale analisi 2: Null, Segnale analisi 3: Null
# Vendite 1: 5, Vendite 2: 4, Vendite 3: 3
# Magazzino 1: (1, 'perfect'), Magazzino 2: (2, 'perfect'), Magazzino 3: (0, 'perfect')
# --------------------------------------------------
# old max price 1: 21.477840383022603
# new max price 1: 22.43986421327942
# old max price 2: 21.477840383022603
# new max price 2: 22.43986421327942
# old max price 3: 21.477840383022603
# new max price 3: 22.43986421327942
# supposed warehouse 1: 0
# context 1: 0
# analisi 1: 1
# supposed warehouse 2: 1
# context 2: 0
# analisi 2: 1
# supposed warehouse 3: 2
# context 3: 0
# analisi 3: 1
# [5, 4, 3]
# Real total demand: 12
# Produzione 1: 5, Produzione 2: 4, Produzione 3: 3
# Segnale analisi 1: Analysis, Segnale analisi 2: Null, Segnale analisi 3: Null
# Vendite 1: 5, Vendite 2: 4, Vendite 3: 3
# Magazzino 1: (1, 'perfect'), Magazzino 2: (2, 'perfect'), Magazzino 3: (0, 'perfect')
# --------------------------------------------------
# old max price 1: 22.43986421327942
# new max price 1: 23.838880033991764
# old max price 2: 22.43986421327942
# new max price 2: 23.838880033991764
# old max price 3: 22.43986421327942
# new max price 3: 23.838880033991764
# supposed warehouse 1: 0
# context 1: 0
# analisi 1: 0
# supposed warehouse 2: 1
# context 2: 0
# analisi 2: 1
# supposed warehouse 3: 2
# context 3: 0
# analisi 3: 1
# [5, 4, 3]
# Real total demand: 12
# Produzione 1: 6, Produzione 2: 5, Produzione 3: 3
# Segnale analisi 1: Null, Segnale analisi 2: Null, Segnale analisi 3: Null
# Vendite 1: 5, Vendite 2: 4, Vendite 3: 3
# Magazzino 1: (2, 'perfect'), Magazzino 2: (3, 'in control'), Magazzino 3: (0, 'perfect')
# --------------------------------------------------
# old max price 1: 23.838880033991764
# new max price 1: 25.025058875720678
# old max price 2: 23.838880033991764
# new max price 2: 25.025058875720678
# old max price 3: 23.838880033991764
# new max price 3: 25.025058875720678
# supposed warehouse 1: 0
# context 1: 0
# analisi 1: 1
# supposed warehouse 2: 1
# context 2: 1
# analisi 2: 1
# supposed warehouse 3: 2
# context 3: 0
# analisi 3: 1
# [5, 4, 3]
# Real total demand: 12
# Produzione 1: 5, Produzione 2: 4, Produzione 3: 3
# Segnale analisi 1: Analysis, Segnale analisi 2: Null, Segnale analisi 3: Null
# Vendite 1: 5, Vendite 2: 4, Vendite 3: 3
# Magazzino 1: (2, 'perfect'), Magazzino 2: (3, 'in control'), Magazzino 3: (0, 'perfect')
# --------------------------------------------------
# old max price 1: 25.025058875720678
# new max price 1: 24.769300897654773
# old max price 2: 25.025058875720678
# new max price 2: 24.769300897654773
# old max price 3: 25.025058875720678
# new max price 3: 24.769300897654773
# supposed warehouse 1: 0
# context 1: 0
# analisi 1: 0
# supposed warehouse 2: 1
# context 2: 1
# analisi 2: 1
# supposed warehouse 3: 2
# context 3: 0
# analisi 3: 1
# [5, 4, 3]
# Real total demand: 12
# Produzione 1: 6, Produzione 2: 4, Produzione 3: 3
# Segnale analisi 1: Null, Segnale analisi 2: Null, Segnale analisi 3: Null
# Vendite 1: 5, Vendite 2: 4, Vendite 3: 3
# Magazzino 1: (3, 'in control'), Magazzino 2: (3, 'in control'), Magazzino 3: (0, 'perfect')
# --------------------------------------------------
# old max price 1: 24.769300897654773
# new max price 1: 20.679872996165493
# old max price 2: 24.769300897654773
# new max price 2: 20.679872996165493
# old max price 3: 24.769300897654773
# new max price 3: 20.679872996165493
# supposed warehouse 1: 1
# context 1: 1
# analisi 1: 1
# supposed warehouse 2: 1
# context 2: 1
# analisi 2: 1
# supposed warehouse 3: 2
# context 3: 0
# analisi 3: 1
# [5, 4, 3]
# Real total demand: 9
# Produzione 1: 0, Produzione 2: 4, Produzione 3: 3
# Segnale analisi 1: Analysis, Segnale analisi 2: Null, Segnale analisi 3: Null
# Vendite 1: 3, Vendite 2: 3, Vendite 3: 3
# Magazzino 1: (0, 'perfect'), Magazzino 2: (4, 'in control'), Magazzino 3: (0, 'perfect')
# --------------------------------------------------
# old max price 1: 20.679872996165493
# new max price 1: 24.639845775826693
# old max price 2: 20.679872996165493
# new max price 2: 24.639845775826693
# old max price 3: 20.679872996165493
# new max price 3: 24.639845775826693
# supposed warehouse 1: 1
# context 1: 0
# analisi 1: 0
# supposed warehouse 2: 3
# context 2: 0
# analisi 2: 1
# supposed warehouse 3: 2
# context 3: 0
# analisi 3: 1
# [3, 3, 3]
# Real total demand: 9
# Produzione 1: 5, Produzione 2: 3, Produzione 3: 3
# Segnale analisi 1: Null, Segnale analisi 2: Null, Segnale analisi 3: Null
# Vendite 1: 3, Vendite 2: 3, Vendite 3: 3
# Magazzino 1: (2, 'perfect'), Magazzino 2: (4, 'in control'), Magazzino 3: (0, 'perfect')
# --------------------------------------------------
# old max price 1: 24.639845775826693
# new max price 1: 24.62480453936748
# old max price 2: 24.639845775826693
# new max price 2: 24.62480453936748
# old max price 3: 24.639845775826693
# new max price 3: 24.62480453936748
# supposed warehouse 1: 1
# context 1: 0
# analisi 1: 1
# supposed warehouse 2: 3
# context 2: 0
# analisi 2: 1
# supposed warehouse 3: 2
# context 3: 0
# analisi 3: 1
# [3, 3, 3]
# Real total demand: 9
# Produzione 1: 5, Produzione 2: 3, Produzione 3: 3
# Segnale analisi 1: Null, Segnale analisi 2: Null, Segnale analisi 3: Null
# Vendite 1: 3, Vendite 2: 3, Vendite 3: 3
# Magazzino 1: (4, 'in control'), Magazzino 2: (4, 'in control'), Magazzino 3: (0, 'perfect')
# --------------------------------------------------
# old max price 1: 24.62480453936748
# new max price 1: 24.527141904535558
# old max price 2: 24.62480453936748
# new max price 2: 24.527141904535558
# old max price 3: 24.62480453936748
# new max price 3: 24.527141904535558
# supposed warehouse 1: 3
# context 1: 1
# analisi 1: 1
# supposed warehouse 2: 3
# context 2: 0
# analisi 2: 1
# supposed warehouse 3: 2
# context 3: 0
# analisi 3: 1
# [3, 3, 3]
# Real total demand: 9
# Produzione 1: 3, Produzione 2: 3, Produzione 3: 3
# Segnale analisi 1: Analysis, Segnale analisi 2: Null, Segnale analisi 3: Null
# Vendite 1: 3, Vendite 2: 3, Vendite 3: 3
# Magazzino 1: (4, 'in control'), Magazzino 2: (4, 'in control'), Magazzino 3: (0, 'perfect')
# --------------------------------------------------
# old max price 1: 24.527141904535558
# new max price 1: 24.41655247641682
# old max price 2: 24.527141904535558
# new max price 2: 24.41655247641682
# old max price 3: 24.527141904535558
# new max price 3: 24.41655247641682
# supposed warehouse 1: 3
# context 1: 0
# analisi 1: 0
# supposed warehouse 2: 3
# context 2: 0
# analisi 2: 1
# supposed warehouse 3: 2
# context 3: 0
# analisi 3: 1
# [3, 3, 3]
# Real total demand: 20
# Produzione 1: 3, Produzione 2: 3, Produzione 3: 3
# Segnale analisi 1: Analysis, Segnale analisi 2: Null, Segnale analisi 3: Null
# Vendite 1: 7, Vendite 2: 7, Vendite 3: 3
# Magazzino 1: (0, 'perfect'), Magazzino 2: (0, 'perfect'), Magazzino 3: (0, 'perfect')
# --------------------------------------------------
# old max price 1: 24.41655247641682
# new max price 1: 18.153646845728197
# old max price 2: 24.41655247641682
# new max price 2: 18.153646845728197
# old max price 3: 24.41655247641682
# new max price 3: 18.153646845728197
# NEW BR 1: 2
# NEW BR 2: 1
# NEW BR 3: 1
# supposed warehouse 1: 2
# context 1: 1
# analisi 1: 0
# supposed warehouse 2: 0
# context 2: 1
# analisi 2: 1
# supposed warehouse 3: 2
# context 3: 0
# analisi 3: 1
# [7, 7, 3]
# Real total demand: 20
# Produzione 1: 2, Produzione 2: 3, Produzione 3: 1
# Segnale analisi 1: Null, Segnale analisi 2: Null, Segnale analisi 3: Null
# Vendite 1: 2, Vendite 2: 3, Vendite 3: 1
# Magazzino 1: (0, 'perfect'), Magazzino 2: (0, 'perfect'), Magazzino 3: (0, 'perfect')
# --------------------------------------------------
# old max price 1: 18.153646845728197
# new max price 1: 32.97639528069245
# old max price 2: 18.153646845728197
# new max price 2: 32.97639528069245
# old max price 3: 18.153646845728197
# new max price 3: 32.97639528069245
# NEW BR 1: 6
# NEW BR 2: 5
# NEW BR 3: 5
# supposed warehouse 1: 1
# context 1: 0
# analisi 1: 1
# supposed warehouse 2: 1
# context 2: 0
# analisi 2: 1
# supposed warehouse 3: 1
# context 3: 0
# analisi 3: 1
# [2, 3, 1]
# Real total demand: 20
# Produzione 1: 6, Produzione 2: 5, Produzione 3: 5
# Segnale analisi 1: Analysis, Segnale analisi 2: Null, Segnale analisi 3: Null
# Vendite 1: 6, Vendite 2: 5, Vendite 3: 5
# Magazzino 1: (0, 'perfect'), Magazzino 2: (0, 'perfect'), Magazzino 3: (0, 'perfect')
# --------------------------------------------------
# old max price 1: 32.97639528069245
# new max price 1: 29.835688723199333
# old max price 2: 32.97639528069245
# new max price 2: 29.835688723199333
# old max price 3: 32.97639528069245
# new max price 3: 29.835688723199333
# supposed warehouse 1: 0
# context 1: 1
# analisi 1: 0
# supposed warehouse 2: 0
# context 2: 1
# analisi 2: 1
# supposed warehouse 3: 1
# context 3: 0
# analisi 3: 1
# [6, 5, 5]
# Real total demand: 20
# Produzione 1: 6, Produzione 2: 6, Produzione 3: 6
# Segnale analisi 1: Analysis, Segnale analisi 2: Null, Segnale analisi 3: Null
# Vendite 1: 6, Vendite 2: 6, Vendite 3: 6
# Magazzino 1: (0, 'perfect'), Magazzino 2: (0, 'perfect'), Magazzino 3: (0, 'perfect')
# --------------------------------------------------
# old max price 1: 29.835688723199333
# new max price 1: 29.08161511054985
# old max price 2: 29.835688723199333
# new max price 2: 29.08161511054985
# old max price 3: 29.835688723199333
# new max price 3: 29.08161511054985
# supposed warehouse 1: 0
# context 1: 1
# analisi 1: 0
# supposed warehouse 2: 0
# context 2: 1
# analisi 2: 1
# supposed warehouse 3: 0
# context 3: 0
# analisi 3: 1
# [6, 6, 6]
# Real total demand: 20
# Produzione 1: 6, Produzione 2: 6, Produzione 3: 6
# Segnale analisi 1: Analysis, Segnale analisi 2: Analysis, Segnale analisi 3: Null
# Vendite 1: 6, Vendite 2: 6, Vendite 3: 6
# Magazzino 1: (0, 'perfect'), Magazzino 2: (0, 'perfect'), Magazzino 3: (0, 'perfect')
# --------------------------------------------------
# old max price 1: 29.08161511054985
# new max price 1: 28.302320637130272
# old max price 2: 29.08161511054985
# new max price 2: 28.302320637130272
# old max price 3: 29.08161511054985
# new max price 3: 28.302320637130272
# supposed warehouse 1: 0
# context 1: 1
# analisi 1: 0
# supposed warehouse 2: 1
# context 2: 1
# analisi 2: 0
# supposed warehouse 3: 0
# context 3: 0
# analisi 3: 1
# [6, 6, 6]
# Real total demand: 20
# Produzione 1: 6, Produzione 2: 6, Produzione 3: 6
# Segnale analisi 1: Analysis, Segnale analisi 2: Null, Segnale analisi 3: Null
# Vendite 1: 6, Vendite 2: 6, Vendite 3: 6
# Magazzino 1: (0, 'perfect'), Magazzino 2: (0, 'perfect'), Magazzino 3: (0, 'perfect')
# --------------------------------------------------
# old max price 1: 28.302320637130272
# new max price 1: 27.629252132772066
# old max price 2: 28.302320637130272
# new max price 2: 27.629252132772066
# old max price 3: 28.302320637130272
# new max price 3: 27.629252132772066
# supposed warehouse 1: 0
# context 1: 1
# analisi 1: 0
# supposed warehouse 2: 0
# context 2: 1
# analisi 2: 1
# supposed warehouse 3: 0
# context 3: 0
# analisi 3: 1
# [6, 6, 6]
# Real total demand: 20
# Produzione 1: 6, Produzione 2: 6, Produzione 3: 6
# Segnale analisi 1: Analysis, Segnale analisi 2: Analysis, Segnale analisi 3: Null
# Vendite 1: 6, Vendite 2: 6, Vendite 3: 6
# Magazzino 1: (0, 'perfect'), Magazzino 2: (0, 'perfect'), Magazzino 3: (0, 'perfect')
# --------------------------------------------------
# old max price 1: 27.629252132772066
# new max price 1: 26.842597911333076
# old max price 2: 27.629252132772066
# new max price 2: 26.842597911333076
# old max price 3: 27.629252132772066
# new max price 3: 26.842597911333076
# supposed warehouse 1: 0
# context 1: 1
# analisi 1: 0
# supposed warehouse 2: 1
# context 2: 1
# analisi 2: 0
# supposed warehouse 3: 0
# context 3: 0
# analisi 3: 1
# [6, 6, 6]
# Real total demand: 20
# Produzione 1: 6, Produzione 2: 6, Produzione 3: 6
# Segnale analisi 1: Analysis, Segnale analisi 2: Null, Segnale analisi 3: Null
# Vendite 1: 6, Vendite 2: 6, Vendite 3: 6
# Magazzino 1: (0, 'perfect'), Magazzino 2: (0, 'perfect'), Magazzino 3: (0, 'perfect')
# --------------------------------------------------
# old max price 1: 26.842597911333076
# new max price 1: 26.501782953517367
# old max price 2: 26.842597911333076
# new max price 2: 26.501782953517367
# old max price 3: 26.842597911333076
# new max price 3: 26.501782953517367
# supposed warehouse 1: 0
# context 1: 1
# analisi 1: 0
# supposed warehouse 2: 0
# context 2: 1
# analisi 2: 1
# supposed warehouse 3: 0
# context 3: 0
# analisi 3: 1
# [6, 6, 6]
# Real total demand: 20
# Produzione 1: 6, Produzione 2: 6, Produzione 3: 6
# Segnale analisi 1: Analysis, Segnale analisi 2: Analysis, Segnale analisi 3: Null
# Vendite 1: 6, Vendite 2: 6, Vendite 3: 6
# Magazzino 1: (0, 'perfect'), Magazzino 2: (0, 'perfect'), Magazzino 3: (0, 'perfect')
# --------------------------------------------------
# old max price 1: 26.501782953517367
# new max price 1: 26.16053229928734
# old max price 2: 26.501782953517367
# new max price 2: 26.16053229928734
# old max price 3: 26.501782953517367
# new max price 3: 26.16053229928734
# supposed warehouse 1: 0
# context 1: 1
# analisi 1: 0
# supposed warehouse 2: 1
# context 2: 1
# analisi 2: 0
# supposed warehouse 3: 0
# context 3: 0
# analisi 3: 1
# [6, 6, 6]
# Real total demand: 20
# Produzione 1: 6, Produzione 2: 6, Produzione 3: 6
# Segnale analisi 1: Analysis, Segnale analisi 2: Null, Segnale analisi 3: Null
# Vendite 1: 6, Vendite 2: 6, Vendite 3: 6
# Magazzino 1: (0, 'perfect'), Magazzino 2: (0, 'perfect'), Magazzino 3: (0, 'perfect')
# --------------------------------------------------
# old max price 1: 26.16053229928734
# new max price 1: 25.939250005638904
# old max price 2: 26.16053229928734
# new max price 2: 25.939250005638904
# old max price 3: 26.16053229928734
# new max price 3: 25.939250005638904

# %% [markdown]
# # Plot

# %%
time = np.arange(T)

# %%
BR_1_real = np.array([
    (30 - 4 * cost_prod_1 + cost_prod_2 + cost_prod_3) / (4 * sensibility) if t < 15 
    else (45 - 4 * cost_prod_1 + cost_prod_2 + cost_prod_3) / (4 * sensibility)
    for t in time
])

BR_2_real = np.array([
    (30 - 4 * cost_prod_2 + cost_prod_3 + cost_prod_1) / (4 * sensibility) if t < 15 
    else (45 - 4 * cost_prod_2 + cost_prod_3 + cost_prod_1) / (4 * sensibility)
    for t in time
])

BR_3_real = np.array([
    (30 - 4 * cost_prod_3 + cost_prod_1 + cost_prod_2) / (4 * sensibility) if t < 15 
    else (45 - 4 * cost_prod_3 + cost_prod_1 + cost_prod_2) / (4 * sensibility)
    for t in time
])

# %%
infer_ware_plot1 = [x + y for x, y in zip(infer_ware1, prod1)]
infer_ware_plot2 = [x + y for x, y in zip(infer_ware2, prod2)]
infer_ware_plot3 = [x + y for x, y in zip(infer_ware3, prod3)]

# %%
# =========================
# Data Setup
# =========================
all_prod = [prod1, prod2, prod3]
all_warehouse = [warehouse1, warehouse2, warehouse3]
all_infer_ware = [infer_ware_plot1, infer_ware_plot2, infer_ware_plot3]
all_sold = [sold1, sold2, sold3]
all_br_hat = [BR_1_plot, BR_2_plot, BR_3_plot]
all_br_real = [BR_1_real, BR_2_real, BR_3_real]
all_epistemic = [epistemic_choice1, epistemic_choice2, epistemic_choisce3]
all_context = [infer_context1, infer_context2, infer_context3]

n_firms = 3
T = len(time)

# =========================
# Aesthetic Setup
# =========================
sns.set(style="white")

plt.rcParams.update({
    "font.size": 12,
    "axes.titlesize": 18,
    "axes.labelsize": 14,
    "xtick.labelsize": 12,
    "ytick.labelsize": 10
})

color_dn, color_analisi = '#df5c5c', '#89f752'
color_ok, color_reduce = '#21eac9', '#fcad33'

palettes = [
    sns.color_palette("viridis", 10),
    sns.color_palette("rocket", 10),
    sns.color_palette("mako", 10)
]

# =========================
# Figure Layout
# =========================
fig = plt.figure(figsize=(22, 11))

gs = fig.add_gridspec(
    nrows=3,
    ncols=n_firms,
    height_ratios=[5, 1, 1],
    hspace=0.12,
    wspace=0.15
)

main_axs = [fig.add_subplot(gs[0, i]) for i in range(n_firms)]
epis_axs = [fig.add_subplot(gs[1, i], sharex=main_axs[i]) for i in range(n_firms)]
cont_axs = [fig.add_subplot(gs[2, i], sharex=main_axs[i]) for i in range(n_firms)]

# =========================
# Desired Ticks
# =========================
desired_ticks = [0, 3, 6, 9, 12, 15, 18, 21, 24]

# =========================
# Plotting Loop
# =========================
for i in range(n_firms):

    ax_m = main_axs[i]
    ax_e = epis_axs[i]
    ax_c = cont_axs[i]

    p = palettes[i]

    c_map = {
        'prod': p[2],
        'ware': p[4],
        'sales': p[6],
        'inf': p[8],
        'br': p[0]
    }

    # MAIN PLOT
    ax_m.bar(time, all_prod[i], width=0.7,
             color=c_map['prod'], alpha=0.9, label='Production')

    ax_m.bar(time, all_warehouse[i][:T], width=0.7,
             bottom=all_prod[i], color=c_map['ware'], alpha=0.6, label='Warehouse')

    ax_m.plot(time, all_infer_ware[i],
              color=c_map['inf'], marker='o',
              linestyle='--', linewidth=2, label='Warehouse hat')

    ax_m.plot(time, all_sold[i],
              color=c_map['sales'], marker='o',
              linestyle='-', linewidth=2, label='Sales')

    ax_m.plot(time, all_br_hat[i],
              color=c_map['br'], linestyle='--',
              linewidth=1.5, label='BR hat')

    ax_m.plot(time, all_br_real[i],
              color='red' if i < 2 else 'blue',
              linestyle='--', linewidth=1.5, label='BR real')

    ax_m.set_title(f'Firm {i+1}', pad=15,
                   fontsize=20, fontweight='bold')

    ax_m.set_ylim(0, 11)
    ax_m.set_yticks(range(12))
    ax_m.grid(axis='y', linestyle='--', alpha=0.3)
    ax_m.tick_params(axis='x', labelbottom=False)

    for spine in ax_m.spines.values():
        spine.set_color('#bbbbbb')
        spine.set_linewidth(1)

    if i == 0:
        ax_m.set_ylabel('Total quantity')

    ax_m.legend(loc='upper left', fontsize=14,
                frameon=True, ncol=2)

    # =========================
    # EPISTEMIC / CONTEXT SQUARES
    # =========================
    for ax_sq, data, colors in zip(
            [ax_e, ax_c],
            [all_epistemic[i], all_context[i]],
            [(color_analisi, color_dn),
             (color_ok, color_reduce)]):

        ax_sq.set_ylim(0, 1)
        ax_sq.set_yticks([])
        ax_sq.set_aspect('equal')

        for t_idx, val in enumerate(data):
            c = colors[int(val)]
            ax_sq.bar(time[t_idx], 1, width=1, color=c,
                      edgecolor='white', linewidth=3)

        ax_sq.set_xlim(time[0]-0.5, time[-1]+0.5)
        for spine in ax_sq.spines.values():
            spine.set_visible(False)

    # =========================
    # PERFECTLY ALIGNED TICKS
    # =========================
    # Calculate tick positions aligned with time
    tick_positions = [time[min(t, len(time)-1)] for t in desired_ticks]

    ax_e.set_xticks(tick_positions)
    ax_c.set_xticks(tick_positions)

    ax_e.set_xticklabels([])  # Hide numbers in the epistemic row
    ax_c.set_xticklabels(desired_ticks)  # Show all ticks including 25

    ax_e.tick_params(axis='x', labelsize=12)
    ax_c.tick_params(axis='x', labelsize=12)

    ax_m.set_xlabel("Time Step")

# =========================
# LEGEND ELEMENTS
# =========================
legend_elements_ep = [
    Line2D([0], [0], marker='s', color='w', label='Analysis',
           markerfacecolor=color_analisi, markersize=12),
    Line2D([0], [0], marker='s', color='w', label='DN',
           markerfacecolor=color_dn, markersize=12)
]

legend_elements_ctx = [
    Line2D([0], [0], marker='s', color='w', label='Acceptable production',
           markerfacecolor=color_ok, markersize=12),
    Line2D([0], [0], marker='s', color='w', label='Reduce production',
           markerfacecolor=color_reduce, markersize=12)
]

fig.legend(handles=legend_elements_ep,
           loc='lower center',
           bbox_to_anchor=(0.445, 0.0075),
           frameon=False,
           fontsize=16,
           ncol=1)

fig.legend(handles=legend_elements_ctx,
           loc='lower center',
           bbox_to_anchor=(0.66, 0.0075),
           frameon=False,
           fontsize=16,
           ncol=1)

fig.text(0.41, 0.05, "Epistemic\nstate",
         ha='right', va='center', fontsize=16, fontweight='bold')

fig.text(0.59, 0.05, "Inferred\ncontext",
         ha='right', va='center', fontsize=16, fontweight='bold')

plt.tight_layout(rect=[0, 0.08, 1, 1])
plt.show()
